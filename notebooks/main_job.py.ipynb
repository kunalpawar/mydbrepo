# %%
#%run "/Workspace/Repos/kunalpawar828@gmail.com/mydbrepo/src/utils.py"

# %%
#%run "/Workspace/Repos/kunalpawar828@gmail.com/mydbrepo/src/transformations.py"

# %%
from src.utils import get_spark

from src.transformations import transform_data

# %%
spark = get_spark()


df = spark.read.table("workspace.default.emp")
result = transform_data(df)

result.write.mode("overwrite").saveAsTable("workspace.default.emp_detail")
