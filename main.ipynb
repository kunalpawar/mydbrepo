# %%
import sys
sys.path.append("/Workspace/Repos/kunalpawar828@gmail.com/mydbrepo")

from src.utils import greet, add_numbers

from src.utils import greet, add_numbers

if __name__ == "__main__":
    print(greet("Databricks User"))
    print(f"5 + 7 = {add_numbers(5,7)}")
